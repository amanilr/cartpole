# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from tqdm import tqdm

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.multioutput import MultiOutputRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from scores.score_logger import ScoreLogger

ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.05
EXPLORATION_DECAY = 0.95
# Out:
# Using TensorFlow backend.

# %%
class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = MultiOutputRegressor(LGBMRegressor(n_estimators=500, n_jobs=-1))
        #self.model = KNeighborsRegressor(n_jobs=-1)
        #self.model = MultiOutputRegressor(SVR(), n_jobs=8)
        self.isFit = False

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        if self.isFit == True:
            q_values = self.model.predict(state)
        else:
            q_values = np.zeros(self.action_space).reshape(1, -1)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, int(len(self.memory)/1))
        X = []
        targets = []
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                if self.isFit:
                    q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
                    #print(self.model.predict(state_next))
                else:
                    q_update = reward
            if self.isFit:
                q_values = self.model.predict(state)
            else:
                q_values = np.zeros(self.action_space).reshape(1, -1)
            q_values[0][action] = q_update
            
            #print(state)
            #print(action)
            #print(q_values)
            X.append(list(state[0]))
            targets.append(q_values[0])
        #print(X)
        #print(targets)
        self.model.fit(X, targets)
        self.isFit = True
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

# %%
env = gym.make(ENV_NAME)
score_logger = ScoreLogger(ENV_NAME)
observation_space = env.observation_space.shape[0]
action_space = env.action_space.n
dqn_solver = DQNSolver(observation_space, action_space)
run = 0
while True:
    run += 1
    state = env.reset()
    state = np.reshape(state, [1, observation_space])
    step = 0
    while True:
        step += 1
        #env.render()
        action = dqn_solver.act(state)
        state_next, reward, terminal, info = env.step(action)
        reward = reward if not terminal else -reward
        state_next = np.reshape(state_next, [1, observation_space])
        dqn_solver.remember(state, action, reward, state_next, terminal)
        state = state_next
        if terminal:
            print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
            score_logger.add_score(step, run)
            break
    dqn_solver.experience_replay()
# Out:
# Run: 1, exploration: 1.0, score: 32
# Scores: (min: 32, avg: 32, max: 32)
#
# Run: 2, exploration: 0.95, score: 18
# Scores: (min: 18, avg: 25, max: 32)
# /home/charles/cartpole/scores/score_logger.py:77: RankWarning: Polyfit may be poorly conditioned
#   z = np.polyfit(np.array(trend_x), np.array(y[1:]), 1)
# Run: 3, exploration: 0.9025, score: 24
# Scores: (min: 18, avg: 24.666666666666668, max: 32)
#
# Run: 4, exploration: 0.8573749999999999, score: 22
# Scores: (min: 18, avg: 24, max: 32)
#
# Run: 5, exploration: 0.8145062499999999, score: 27
# Scores: (min: 18, avg: 24.6, max: 32)
#
# Run: 6, exploration: 0.7737809374999999, score: 40
# Scores: (min: 18, avg: 27.166666666666668, max: 40)
#
# Run: 7, exploration: 0.7350918906249998, score: 31
# Scores: (min: 18, avg: 27.714285714285715, max: 40)
#
# Run: 8, exploration: 0.6983372960937497, score: 20
# Scores: (min: 18, avg: 26.75, max: 40)
#
# Run: 9, exploration: 0.6634204312890623, score: 18
# Scores: (min: 18, avg: 25.77777777777778, max: 40)
#
# Run: 10, exploration: 0.6302494097246091, score: 26
# Scores: (min: 18, avg: 25.8, max: 40)
#
# Run: 11, exploration: 0.5987369392383786, score: 19
# Scores: (min: 18, avg: 25.181818181818183, max: 40)
#
# Run: 12, exploration: 0.5688000922764596, score: 40
# Scores: (min: 18, avg: 26.416666666666668, max: 40)
#
# Run: 13, exploration: 0.5403600876626365, score: 21
# Scores: (min: 18, avg: 26, max: 40)
#
# Run: 14, exploration: 0.5133420832795047, score: 28
# Scores: (min: 18, avg: 26.142857142857142, max: 40)
#
# Run: 15, exploration: 0.48767497911552943, score: 32
# Scores: (min: 18, avg: 26.533333333333335, max: 40)
#
# Run: 16, exploration: 0.46329123015975293, score: 42
# Scores: (min: 18, avg: 27.5, max: 42)
#
# Run: 17, exploration: 0.44012666865176525, score: 52
# Scores: (min: 18, avg: 28.941176470588236, max: 52)
#
# Run: 18, exploration: 0.41812033521917696, score: 48
# Scores: (min: 18, avg: 30, max: 52)
#
# Run: 19, exploration: 0.3972143184582181, score: 15
# Scores: (min: 15, avg: 29.210526315789473, max: 52)
#
# Run: 20, exploration: 0.37735360253530714, score: 13
# Scores: (min: 13, avg: 28.4, max: 52)
#
# Run: 21, exploration: 0.35848592240854177, score: 16
# Scores: (min: 13, avg: 27.80952380952381, max: 52)
#
# Run: 22, exploration: 0.34056162628811465, score: 21
# Scores: (min: 13, avg: 27.5, max: 52)
#
# Run: 23, exploration: 0.3235335449737089, score: 40
# Scores: (min: 13, avg: 28.043478260869566, max: 52)
#
# Run: 24, exploration: 0.30735686772502346, score: 39
# Scores: (min: 13, avg: 28.5, max: 52)
#
# Run: 25, exploration: 0.2919890243387723, score: 40
# Scores: (min: 13, avg: 28.96, max: 52)
#
# Run: 26, exploration: 0.27738957312183365, score: 22
# Scores: (min: 13, avg: 28.692307692307693, max: 52)
#
# Run: 27, exploration: 0.263520094465742, score: 42
# Scores: (min: 13, avg: 29.185185185185187, max: 52)
#
# Run: 28, exploration: 0.25034408974245487, score: 23
# Scores: (min: 13, avg: 28.964285714285715, max: 52)
#
# Run: 29, exploration: 0.2378268852553321, score: 31
# Scores: (min: 13, avg: 29.03448275862069, max: 52)
#
# Run: 30, exploration: 0.2259355409925655, score: 35
# Scores: (min: 13, avg: 29.233333333333334, max: 52)
#
# Run: 31, exploration: 0.2146387639429372, score: 29
# Scores: (min: 13, avg: 29.225806451612904, max: 52)
#
# Run: 32, exploration: 0.20390682574579033, score: 36
# Scores: (min: 13, avg: 29.4375, max: 52)
#
# Run: 33, exploration: 0.1937114844585008, score: 64
# Scores: (min: 13, avg: 30.484848484848484, max: 64)
#
# Run: 34, exploration: 0.18402591023557577, score: 58
# Scores: (min: 13, avg: 31.294117647058822, max: 64)
#
# Run: 35, exploration: 0.17482461472379698, score: 29
# Scores: (min: 13, avg: 31.228571428571428, max: 64)
#
# Run: 36, exploration: 0.16608338398760714, score: 19
# Scores: (min: 13, avg: 30.88888888888889, max: 64)
#
# Run: 37, exploration: 0.15777921478822676, score: 61
# Scores: (min: 13, avg: 31.7027027027027, max: 64)
#
# Run: 38, exploration: 0.14989025404881542, score: 35
# Scores: (min: 13, avg: 31.789473684210527, max: 64)
#
# Run: 39, exploration: 0.14239574134637464, score: 83
# Scores: (min: 13, avg: 33.1025641025641, max: 83)
#
# Run: 40, exploration: 0.1352759542790559, score: 54
# Scores: (min: 13, avg: 33.625, max: 83)
#
# Run: 41, exploration: 0.1285121565651031, score: 27
# Scores: (min: 13, avg: 33.46341463414634, max: 83)
#
# Run: 42, exploration: 0.12208654873684793, score: 157
# Scores: (min: 13, avg: 36.404761904761905, max: 157)
#
# Run: 43, exploration: 0.11598222130000553, score: 43
# Scores: (min: 13, avg: 36.55813953488372, max: 157)
#
# Run: 44, exploration: 0.11018311023500525, score: 97
# Scores: (min: 13, avg: 37.93181818181818, max: 157)
#
# Run: 45, exploration: 0.10467395472325498, score: 31
# Scores: (min: 13, avg: 37.77777777777778, max: 157)
#
# Run: 46, exploration: 0.09944025698709223, score: 72
# Scores: (min: 13, avg: 38.52173913043478, max: 157)
#
# Run: 47, exploration: 0.09446824413773762, score: 37
# Scores: (min: 13, avg: 38.48936170212766, max: 157)
#
# Run: 48, exploration: 0.08974483193085074, score: 47
# Scores: (min: 13, avg: 38.666666666666664, max: 157)
#
# Run: 49, exploration: 0.0852575903343082, score: 60
# Scores: (min: 13, avg: 39.10204081632653, max: 157)
#
# Run: 50, exploration: 0.08099471081759278, score: 113
# Scores: (min: 13, avg: 40.58, max: 157)
#
# Run: 51, exploration: 0.07694497527671314, score: 80
# Scores: (min: 13, avg: 41.35294117647059, max: 157)
#
# Run: 52, exploration: 0.07309772651287748, score: 86
# Scores: (min: 13, avg: 42.21153846153846, max: 157)
#
# Run: 53, exploration: 0.0694428401872336, score: 105
# Scores: (min: 13, avg: 43.39622641509434, max: 157)
#
# Run: 54, exploration: 0.0659706981778719, score: 72
# Scores: (min: 13, avg: 43.925925925925924, max: 157)
#
# Run: 55, exploration: 0.0626721632689783, score: 100
# Scores: (min: 13, avg: 44.945454545454545, max: 157)
#
# Run: 56, exploration: 0.059538555105529384, score: 155
# Scores: (min: 13, avg: 46.910714285714285, max: 157)
#
# Run: 57, exploration: 0.05656162735025291, score: 78
# Scores: (min: 13, avg: 47.45614035087719, max: 157)
#
# Run: 58, exploration: 0.053733545982740265, score: 61
# Scores: (min: 13, avg: 47.689655172413794, max: 157)
#
# Run: 59, exploration: 0.05104686868360325, score: 59
# Scores: (min: 13, avg: 47.88135593220339, max: 157)
#
# Run: 60, exploration: 0.05, score: 42
# Scores: (min: 13, avg: 47.78333333333333, max: 157)
#
# Run: 61, exploration: 0.05, score: 125
# Scores: (min: 13, avg: 49.049180327868854, max: 157)
#
# Run: 62, exploration: 0.05, score: 160
# Scores: (min: 13, avg: 50.83870967741935, max: 160)
#
# Run: 63, exploration: 0.05, score: 72
# Scores: (min: 13, avg: 51.17460317460318, max: 160)
#
# Run: 64, exploration: 0.05, score: 89
# Scores: (min: 13, avg: 51.765625, max: 160)
#
# Run: 65, exploration: 0.05, score: 101
# Scores: (min: 13, avg: 52.52307692307692, max: 160)
#
# Run: 66, exploration: 0.05, score: 118
# Scores: (min: 13, avg: 53.515151515151516, max: 160)
#
# Run: 67, exploration: 0.05, score: 88
# Scores: (min: 13, avg: 54.02985074626866, max: 160)
#
# Run: 68, exploration: 0.05, score: 75
# Scores: (min: 13, avg: 54.338235294117645, max: 160)
#
# Run: 69, exploration: 0.05, score: 64
# Scores: (min: 13, avg: 54.47826086956522, max: 160)
#
# Run: 70, exploration: 0.05, score: 144
# Scores: (min: 13, avg: 55.75714285714286, max: 160)
#
# Run: 71, exploration: 0.05, score: 198
# Scores: (min: 13, avg: 57.76056338028169, max: 198)
#
# Run: 72, exploration: 0.05, score: 113
# Scores: (min: 13, avg: 58.52777777777778, max: 198)
#
# Run: 73, exploration: 0.05, score: 110
# Scores: (min: 13, avg: 59.23287671232877, max: 198)
#
# Run: 74, exploration: 0.05, score: 182
# Scores: (min: 13, avg: 60.891891891891895, max: 198)
#
# Run: 75, exploration: 0.05, score: 106
# Scores: (min: 13, avg: 61.49333333333333, max: 198)
#
# Run: 76, exploration: 0.05, score: 147
# Scores: (min: 13, avg: 62.61842105263158, max: 198)
#
# Run: 77, exploration: 0.05, score: 143
# Scores: (min: 13, avg: 63.66233766233766, max: 198)
#
# Run: 78, exploration: 0.05, score: 171
# Scores: (min: 13, avg: 65.03846153846153, max: 198)
#
# Run: 79, exploration: 0.05, score: 86
# Scores: (min: 13, avg: 65.30379746835443, max: 198)
#
# Run: 80, exploration: 0.05, score: 138
# Scores: (min: 13, avg: 66.2125, max: 198)
#
# Run: 81, exploration: 0.05, score: 158
# Scores: (min: 13, avg: 67.34567901234568, max: 198)
#
# Run: 82, exploration: 0.05, score: 162
# Scores: (min: 13, avg: 68.5, max: 198)
#
# Run: 83, exploration: 0.05, score: 134
# Scores: (min: 13, avg: 69.28915662650603, max: 198)
#
# Run: 84, exploration: 0.05, score: 150
# Scores: (min: 13, avg: 70.25, max: 198)
#
# Run: 85, exploration: 0.05, score: 195
# Scores: (min: 13, avg: 71.71764705882353, max: 198)
#
# Run: 86, exploration: 0.05, score: 101
# Scores: (min: 13, avg: 72.05813953488372, max: 198)
# Run: 87, exploration: 0.05, score: 76
# Scores: (min: 13, avg: 72.10344827586206, max: 198)
#
# Run: 88, exploration: 0.05, score: 209
# Scores: (min: 13, avg: 73.6590909090909, max: 209)
#
# Run: 89, exploration: 0.05, score: 97
# Scores: (min: 13, avg: 73.92134831460675, max: 209)
#
# Run: 90, exploration: 0.05, score: 171
# Scores: (min: 13, avg: 75, max: 209)
#
# Run: 91, exploration: 0.05, score: 124
# Scores: (min: 13, avg: 75.53846153846153, max: 209)
#
# Run: 92, exploration: 0.05, score: 163
# Scores: (min: 13, avg: 76.48913043478261, max: 209)
#
# Run: 93, exploration: 0.05, score: 234
# Scores: (min: 13, avg: 78.18279569892474, max: 234)
#
# Run: 94, exploration: 0.05, score: 161
# Scores: (min: 13, avg: 79.06382978723404, max: 234)
#
# Run: 95, exploration: 0.05, score: 191
# Scores: (min: 13, avg: 80.2421052631579, max: 234)
#
# Run: 96, exploration: 0.05, score: 187
# Scores: (min: 13, avg: 81.35416666666667, max: 234)
#
# Run: 97, exploration: 0.05, score: 129
# Scores: (min: 13, avg: 81.84536082474227, max: 234)
#
# Run: 98, exploration: 0.05, score: 303
# Scores: (min: 13, avg: 84.10204081632654, max: 303)
#
# Run: 99, exploration: 0.05, score: 330
# Scores: (min: 13, avg: 86.58585858585859, max: 330)
#
# Run: 100, exploration: 0.05, score: 310
# Scores: (min: 13, avg: 88.82, max: 330)
#
# Run: 101, exploration: 0.05, score: 151
# Scores: (min: 13, avg: 90.01, max: 330)
#
# Run: 102, exploration: 0.05, score: 202
# Scores: (min: 13, avg: 91.85, max: 330)
#
# Run: 103, exploration: 0.05, score: 298
# Scores: (min: 13, avg: 94.59, max: 330)
#
# Run: 104, exploration: 0.05, score: 500
# Scores: (min: 13, avg: 99.37, max: 500)
#
# Run: 105, exploration: 0.05, score: 500
# Scores: (min: 13, avg: 104.1, max: 500)
#
# Run: 106, exploration: 0.05, score: 329
# Scores: (min: 13, avg: 106.99, max: 500)
#
# Run: 107, exploration: 0.05, score: 500
# Scores: (min: 13, avg: 111.68, max: 500)
#
# Run: 108, exploration: 0.05, score: 500
# Scores: (min: 13, avg: 116.48, max: 500)
#
# Run: 109, exploration: 0.05, score: 404
# Scores: (min: 13, avg: 120.34, max: 500)
#
# Run: 110, exploration: 0.05, score: 244
# Scores: (min: 13, avg: 122.52, max: 500)
#
# Run: 111, exploration: 0.05, score: 339
# Scores: (min: 13, avg: 125.72, max: 500)
#
# Run: 112, exploration: 0.05, score: 199
# Scores: (min: 13, avg: 127.31, max: 500)
#
# Run: 113, exploration: 0.05, score: 500
# Scores: (min: 13, avg: 132.1, max: 500)
#
# Run: 114, exploration: 0.05, score: 97
# Scores: (min: 13, avg: 132.79, max: 500)
#
# Run: 115, exploration: 0.05, score: 238
# Scores: (min: 13, avg: 134.85, max: 500)
#
# Run: 116, exploration: 0.05, score: 254
# Scores: (min: 13, avg: 136.97, max: 500)
#
# Run: 117, exploration: 0.05, score: 195
# Scores: (min: 13, avg: 138.4, max: 500)
#
# Run: 118, exploration: 0.05, score: 319
# Scores: (min: 13, avg: 141.11, max: 500)
#
# Run: 119, exploration: 0.05, score: 227
# Scores: (min: 13, avg: 143.23, max: 500)
#
# Run: 120, exploration: 0.05, score: 221
# Scores: (min: 16, avg: 145.31, max: 500)
#
# Run: 121, exploration: 0.05, score: 438
# Scores: (min: 19, avg: 149.53, max: 500)
#
# Run: 122, exploration: 0.05, score: 279
# Scores: (min: 19, avg: 152.11, max: 500)
#
# Run: 123, exploration: 0.05, score: 271
# Scores: (min: 19, avg: 154.42, max: 500)
#
# Run: 124, exploration: 0.05, score: 200
# Scores: (min: 19, avg: 156.03, max: 500)
#
# Run: 125, exploration: 0.05, score: 491
# Scores: (min: 19, avg: 160.54, max: 500)
#
# Run: 126, exploration: 0.05, score: 222
# Scores: (min: 19, avg: 162.54, max: 500)
#
# Run: 127, exploration: 0.05, score: 192
# Scores: (min: 19, avg: 164.04, max: 500)
#
# Run: 128, exploration: 0.05, score: 152
# Scores: (min: 19, avg: 165.33, max: 500)
#
# Run: 129, exploration: 0.05, score: 126
# Scores: (min: 19, avg: 166.28, max: 500)
#
# Run: 130, exploration: 0.05, score: 150
# Scores: (min: 19, avg: 167.43, max: 500)
#
# Run: 131, exploration: 0.05, score: 342
# Scores: (min: 19, avg: 170.56, max: 500)
#
# Run: 132, exploration: 0.05, score: 196
# Scores: (min: 19, avg: 172.16, max: 500)
#
# Run: 133, exploration: 0.05, score: 260
# Scores: (min: 19, avg: 174.12, max: 500)
#
# Run: 134, exploration: 0.05, score: 232
# Scores: (min: 19, avg: 175.86, max: 500)
#
# Run: 135, exploration: 0.05, score: 40
# Scores: (min: 19, avg: 175.97, max: 500)
#
# Run: 136, exploration: 0.05, score: 374
# Scores: (min: 27, avg: 179.52, max: 500)
#
# Run: 137, exploration: 0.05, score: 158
# Scores: (min: 27, avg: 180.49, max: 500)
#
# Run: 138, exploration: 0.05, score: 148
# Scores: (min: 27, avg: 181.62, max: 500)
#
# Run: 139, exploration: 0.05, score: 308
# Scores: (min: 27, avg: 183.87, max: 500)
#
# Run: 140, exploration: 0.05, score: 266
# Scores: (min: 27, avg: 185.99, max: 500)
#
# Run: 141, exploration: 0.05, score: 270
# Scores: (min: 31, avg: 188.42, max: 500)
#
# Run: 142, exploration: 0.05, score: 180
# Scores: (min: 31, avg: 188.65, max: 500)
#
# Run: 143, exploration: 0.05, score: 356
# Scores: (min: 31, avg: 191.78, max: 500)
#
# Run: 144, exploration: 0.05, score: 423
# Scores: (min: 31, avg: 195.04, max: 500)
#
# Solved in 44 runs, 144 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3f2c2c1f880f> in <module>()
#      21         if terminal:
#      22             print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 23             score_logger.add_score(step, run)
#      24             break
#      25     dqn_solver.experience_replay()
#
# ~/cartpole/scores/score_logger.py in add_score(self, score, run)
#      52                            show_trend=False,
#      53                            show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined
