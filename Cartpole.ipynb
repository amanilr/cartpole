# %%
import random
import gym
import numpy as np
from collections import deque


from sklearn.multioutput import MultiOutputRegressor
from lightgbm import LGBMRegressor
from scores.score_logger import ScoreLogger
from sklearn.model_selection import train_test_split

ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.05
EXPLORATION_DECAY = 0.96

# %%
class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = MultiOutputRegressor(LGBMRegressor(n_estimators=100, n_jobs=-1))
        #self.model = KNeighborsRegressor(n_jobs=-1)
        #self.model = MultiOutputRegressor(SVR(), n_jobs=8)
        self.isFit = False

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        if self.isFit == True:
            q_values = self.model.predict(state)
        else:
            q_values = np.zeros(self.action_space).reshape(1, -1)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, int(len(self.memory)/1))
        X = []
        targets = []
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                if self.isFit:
                    q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
                    #print(self.model.predict(state_next))
                else:
                    q_update = reward
            if self.isFit:
                q_values = self.model.predict(state)
            else:
                q_values = np.zeros(self.action_space).reshape(1, -1)
            q_values[0][action] = q_update
            
            #print(state)
            #print(action)
            #print(q_values)
            X.append(list(state[0]))
            targets.append(q_values[0])
        #print(X)
        #print(targets)
        self.model.fit(X, targets)
        self.isFit = True
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

# %%
env = gym.make(ENV_NAME)
score_logger = ScoreLogger(ENV_NAME)
observation_space = env.observation_space.shape[0]
action_space = env.action_space.n
dqn_solver = DQNSolver(observation_space, action_space)
run = 0
while True:
    run += 1
    state = env.reset()
    state = np.reshape(state, [1, observation_space])
    step = 0
    while True:
        step += 1
        #env.render()
        action = dqn_solver.act(state)
        state_next, reward, terminal, info = env.step(action)
        reward = reward if not terminal else -reward
        state_next = np.reshape(state_next, [1, observation_space])
        dqn_solver.remember(state, action, reward, state_next, terminal)
        state = state_next
        if terminal:
            print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
            score_logger.add_score(step, run)
            break
    dqn_solver.experience_replay()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 1.0, score: 13
# G:\GitProjects\cartpole\scores\score_logger.py:81: RankWarning: Polyfit may be poorly conditioned
#   z = np.polyfit(np.array(trend_x), np.array(y[1:]), 1)
# Scores: (min: 13, avg: 14, max: 15)
#
# Run: 3, exploration: 0.96, score: 15
# Scores: (min: 13, avg: 14.333333333333334, max: 15)
#
# Run: 4, exploration: 0.9216, score: 13
# Scores: (min: 13, avg: 14, max: 15)
#
# Run: 5, exploration: 0.884736, score: 18
# Scores: (min: 13, avg: 14.8, max: 18)
#
# Run: 6, exploration: 0.84934656, score: 9
# Scores: (min: 9, avg: 13.833333333333334, max: 18)
#
# Run: 7, exploration: 0.8153726976, score: 15
# Scores: (min: 9, avg: 14, max: 18)
#
# Run: 8, exploration: 0.782757789696, score: 15
# Scores: (min: 9, avg: 14.125, max: 18)
#
# Run: 9, exploration: 0.7514474781081599, score: 11
# Scores: (min: 9, avg: 13.777777777777779, max: 18)
#
# Run: 10, exploration: 0.7213895789838335, score: 19
# Scores: (min: 9, avg: 14.3, max: 19)
#
# Run: 11, exploration: 0.6925339958244802, score: 20
# Scores: (min: 9, avg: 14.818181818181818, max: 20)
#
# Run: 12, exploration: 0.6648326359915009, score: 16
# Scores: (min: 9, avg: 14.916666666666666, max: 20)
#
# Run: 13, exploration: 0.6382393305518408, score: 16
# Scores: (min: 9, avg: 15, max: 20)
#
# Run: 14, exploration: 0.6127097573297672, score: 15
# Scores: (min: 9, avg: 15, max: 20)
#
# Run: 15, exploration: 0.5882013670365764, score: 12
# Scores: (min: 9, avg: 14.8, max: 20)
#
# Run: 16, exploration: 0.5646733123551133, score: 17
# Scores: (min: 9, avg: 14.9375, max: 20)
#
# Run: 17, exploration: 0.5420863798609088, score: 22
# Scores: (min: 9, avg: 15.352941176470589, max: 22)
#
# Run: 18, exploration: 0.5204029246664724, score: 22
# Scores: (min: 9, avg: 15.722222222222221, max: 22)
#
# Run: 19, exploration: 0.4995868076798135, score: 30
# Scores: (min: 9, avg: 16.473684210526315, max: 30)
#
# Run: 20, exploration: 0.47960333537262095, score: 12
# Scores: (min: 9, avg: 16.25, max: 30)
#
# Run: 21, exploration: 0.4604192019577161, score: 32
# Scores: (min: 9, avg: 17, max: 32)
#
# Run: 22, exploration: 0.4420024338794074, score: 15
# Scores: (min: 9, avg: 16.90909090909091, max: 32)
#
# Run: 23, exploration: 0.42432233652423107, score: 32
# Scores: (min: 9, avg: 17.565217391304348, max: 32)
#
# Run: 24, exploration: 0.4073494430632618, score: 16
# Scores: (min: 9, avg: 17.5, max: 32)
#
# Run: 25, exploration: 0.3910554653407313, score: 18
# Scores: (min: 9, avg: 17.52, max: 32)
#
# Run: 26, exploration: 0.3754132467271021, score: 23
# Scores: (min: 9, avg: 17.73076923076923, max: 32)
#
# Run: 27, exploration: 0.360396716858018, score: 54
# Scores: (min: 9, avg: 19.074074074074073, max: 54)
#
# Run: 28, exploration: 0.3459808481836973, score: 58
# Scores: (min: 9, avg: 20.464285714285715, max: 58)
#
# Run: 29, exploration: 0.33214161425634936, score: 57
# Scores: (min: 9, avg: 21.724137931034484, max: 58)
#
# Run: 30, exploration: 0.3188559496860954, score: 33
# Scores: (min: 9, avg: 22.1, max: 58)
#
# Run: 31, exploration: 0.3061017116986515, score: 67
# Scores: (min: 9, avg: 23.548387096774192, max: 67)
#
# Run: 32, exploration: 0.29385764323070546, score: 26
# Scores: (min: 9, avg: 23.625, max: 67)
#
# Run: 33, exploration: 0.2821033375014772, score: 34
# Scores: (min: 9, avg: 23.939393939393938, max: 67)
#
# Run: 34, exploration: 0.2708192040014181, score: 18
# Scores: (min: 9, avg: 23.764705882352942, max: 67)
#
# Run: 35, exploration: 0.2599864358413614, score: 46
# Scores: (min: 9, avg: 24.4, max: 67)
#
# Run: 36, exploration: 0.2495869784077069, score: 49
# Scores: (min: 9, avg: 25.083333333333332, max: 67)
#
# Run: 37, exploration: 0.23960349927139862, score: 70
# Scores: (min: 9, avg: 26.2972972972973, max: 70)
#
# Run: 38, exploration: 0.23001935930054268, score: 34
# Scores: (min: 9, avg: 26.5, max: 70)
#
# Run: 39, exploration: 0.22081858492852097, score: 101
# Scores: (min: 9, avg: 28.41025641025641, max: 101)
#
# Run: 40, exploration: 0.21198584153138011, score: 19
# Scores: (min: 9, avg: 28.175, max: 101)
#
# Run: 41, exploration: 0.2035064078701249, score: 63
# Scores: (min: 9, avg: 29.024390243902438, max: 101)
#
# Run: 42, exploration: 0.1953661515553199, score: 50
# Scores: (min: 9, avg: 29.523809523809526, max: 101)
#
# Run: 43, exploration: 0.1875515054931071, score: 91
# Scores: (min: 9, avg: 30.953488372093023, max: 101)
#
# Run: 44, exploration: 0.1800494452733828, score: 56
# Scores: (min: 9, avg: 31.522727272727273, max: 101)
#
# Run: 45, exploration: 0.17284746746244747, score: 78
# Scores: (min: 9, avg: 32.55555555555556, max: 101)
#
# Run: 46, exploration: 0.16593356876394957, score: 102
# Scores: (min: 9, avg: 34.06521739130435, max: 102)
#
# Run: 47, exploration: 0.15929622601339158, score: 67
# Scores: (min: 9, avg: 34.765957446808514, max: 102)
#
# Run: 48, exploration: 0.1529243769728559, score: 98
# Scores: (min: 9, avg: 36.083333333333336, max: 102)
#
# Run: 49, exploration: 0.14680740189394167, score: 107
# Scores: (min: 9, avg: 37.53061224489796, max: 107)
#
# Run: 50, exploration: 0.140935105818184, score: 98
# Scores: (min: 9, avg: 38.74, max: 107)
#
# Run: 51, exploration: 0.13529770158545662, score: 120
# Scores: (min: 9, avg: 40.333333333333336, max: 120)
#
# Run: 52, exploration: 0.12988579352203836, score: 190
# Scores: (min: 9, avg: 43.21153846153846, max: 190)
#
# Run: 53, exploration: 0.12469036178115682, score: 173
# Scores: (min: 9, avg: 45.660377358490564, max: 190)
#
# Run: 54, exploration: 0.11970274730991054, score: 90
# Scores: (min: 9, avg: 46.48148148148148, max: 190)
#
# Run: 55, exploration: 0.11491463741751412, score: 138
# Scores: (min: 9, avg: 48.14545454545455, max: 190)
#
# Run: 56, exploration: 0.11031805192081355, score: 98
# Scores: (min: 9, avg: 49.035714285714285, max: 190)
#
# Run: 57, exploration: 0.105905329843981, score: 118
# Scores: (min: 9, avg: 50.24561403508772, max: 190)
#
# Run: 58, exploration: 0.10166911665022176, score: 125
# Scores: (min: 9, avg: 51.53448275862069, max: 190)
#
# Run: 59, exploration: 0.09760235198421288, score: 118
# Scores: (min: 9, avg: 52.66101694915254, max: 190)
#
# Run: 60, exploration: 0.09369825790484436, score: 132
# Scores: (min: 9, avg: 53.983333333333334, max: 190)
#
# Run: 61, exploration: 0.08995032758865058, score: 113
# Scores: (min: 9, avg: 54.950819672131146, max: 190)
#
# Run: 62, exploration: 0.08635231448510455, score: 110
# Scores: (min: 9, avg: 55.83870967741935, max: 190)
#
# Run: 63, exploration: 0.08289822190570037, score: 112
# Scores: (min: 9, avg: 56.73015873015873, max: 190)
#
# Run: 64, exploration: 0.07958229302947235, score: 136
# Scores: (min: 9, avg: 57.96875, max: 190)
#
# Run: 65, exploration: 0.07639900130829345, score: 118
# Scores: (min: 9, avg: 58.89230769230769, max: 190)
#
# Run: 66, exploration: 0.07334304125596171, score: 100
# Scores: (min: 9, avg: 59.515151515151516, max: 190)
#
# Run: 67, exploration: 0.07040931960572323, score: 102
# Scores: (min: 9, avg: 60.149253731343286, max: 190)
#
# Run: 68, exploration: 0.0675929468214943, score: 130
# Scores: (min: 9, avg: 61.1764705882353, max: 190)
#
# Run: 69, exploration: 0.06488922894863453, score: 168
# Scores: (min: 9, avg: 62.72463768115942, max: 190)
#
# Run: 70, exploration: 0.06229365979068914, score: 120
# Scores: (min: 9, avg: 63.542857142857144, max: 190)
#
# Run: 71, exploration: 0.059801913399061574, score: 116
# Scores: (min: 9, avg: 64.28169014084507, max: 190)
#
# Run: 72, exploration: 0.05740983686309911, score: 100
# Scores: (min: 9, avg: 64.77777777777777, max: 190)
#
# Run: 73, exploration: 0.05511344338857514, score: 115
# Scores: (min: 9, avg: 65.46575342465754, max: 190)
#
# Run: 74, exploration: 0.052908905653032134, score: 115
# Scores: (min: 9, avg: 66.13513513513513, max: 190)
#
# Run: 75, exploration: 0.050792549426910846, score: 97
# Scores: (min: 9, avg: 66.54666666666667, max: 190)
#
# Run: 76, exploration: 0.05, score: 102
# Scores: (min: 9, avg: 67.01315789473684, max: 190)
#
# Run: 77, exploration: 0.05, score: 128
# Scores: (min: 9, avg: 67.8051948051948, max: 190)
#
# Run: 78, exploration: 0.05, score: 124
# Scores: (min: 9, avg: 68.52564102564102, max: 190)
#
# Run: 79, exploration: 0.05, score: 114
# Scores: (min: 9, avg: 69.10126582278481, max: 190)
#
# Run: 80, exploration: 0.05, score: 110
# Scores: (min: 9, avg: 69.6125, max: 190)
#
# Run: 81, exploration: 0.05, score: 106
# Scores: (min: 9, avg: 70.06172839506173, max: 190)
#
# Run: 82, exploration: 0.05, score: 77
# Scores: (min: 9, avg: 70.14634146341463, max: 190)
#
# Run: 83, exploration: 0.05, score: 119
# Scores: (min: 9, avg: 70.73493975903614, max: 190)
#
# Run: 84, exploration: 0.05, score: 114
# Scores: (min: 9, avg: 71.25, max: 190)
#
# Run: 85, exploration: 0.05, score: 106
# Scores: (min: 9, avg: 71.65882352941176, max: 190)
# Run: 86, exploration: 0.05, score: 117
# Scores: (min: 9, avg: 72.18604651162791, max: 190)
#
# Run: 87, exploration: 0.05, score: 116
# Scores: (min: 9, avg: 72.6896551724138, max: 190)
#
# Run: 88, exploration: 0.05, score: 109
# Scores: (min: 9, avg: 73.10227272727273, max: 190)
#
# Run: 89, exploration: 0.05, score: 120
# Scores: (min: 9, avg: 73.62921348314607, max: 190)
#
# Run: 90, exploration: 0.05, score: 109
# Scores: (min: 9, avg: 74.02222222222223, max: 190)
#
# Run: 91, exploration: 0.05, score: 114
# Scores: (min: 9, avg: 74.46153846153847, max: 190)
#
# Run: 92, exploration: 0.05, score: 111
# Scores: (min: 9, avg: 74.8586956521739, max: 190)
#
# Run: 93, exploration: 0.05, score: 106
# Scores: (min: 9, avg: 75.19354838709677, max: 190)
#
# Run: 94, exploration: 0.05, score: 103
# Scores: (min: 9, avg: 75.48936170212765, max: 190)
#
# Run: 95, exploration: 0.05, score: 107
# Scores: (min: 9, avg: 75.82105263157895, max: 190)
#
# Run: 96, exploration: 0.05, score: 106
# Scores: (min: 9, avg: 76.13541666666667, max: 190)
#
# Run: 97, exploration: 0.05, score: 115
# Scores: (min: 9, avg: 76.5360824742268, max: 190)
#
# Run: 98, exploration: 0.05, score: 102
# Scores: (min: 9, avg: 76.79591836734694, max: 190)
#
# Run: 99, exploration: 0.05, score: 105
# Scores: (min: 9, avg: 77.08080808080808, max: 190)
#
# Run: 100, exploration: 0.05, score: 106
# Scores: (min: 9, avg: 77.37, max: 190)
#
# Run: 101, exploration: 0.05, score: 101
# Scores: (min: 9, avg: 78.23, max: 190)
#
# Run: 102, exploration: 0.05, score: 111
# Scores: (min: 9, avg: 79.21, max: 190)
#
# Run: 103, exploration: 0.05, score: 104
# Scores: (min: 9, avg: 80.1, max: 190)
#
# Run: 104, exploration: 0.05, score: 110
# Scores: (min: 9, avg: 81.07, max: 190)
#
# Run: 105, exploration: 0.05, score: 102
# Scores: (min: 9, avg: 81.91, max: 190)
#
# Run: 106, exploration: 0.05, score: 111
# Scores: (min: 11, avg: 82.93, max: 190)
#
# Run: 107, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 83.86, max: 190)
#
# Run: 108, exploration: 0.05, score: 105
# Scores: (min: 11, avg: 84.76, max: 190)
#
# Run: 109, exploration: 0.05, score: 108
# Scores: (min: 12, avg: 85.73, max: 190)
#
# Run: 110, exploration: 0.05, score: 119
# Scores: (min: 12, avg: 86.73, max: 190)
#
# Run: 111, exploration: 0.05, score: 110
# Scores: (min: 12, avg: 87.63, max: 190)
#
# Run: 112, exploration: 0.05, score: 111
# Scores: (min: 12, avg: 88.58, max: 190)
#
# Run: 113, exploration: 0.05, score: 107
# Scores: (min: 12, avg: 89.49, max: 190)
#
# Run: 114, exploration: 0.05, score: 106
# Scores: (min: 12, avg: 90.4, max: 190)
#
# Run: 115, exploration: 0.05, score: 112
# Scores: (min: 12, avg: 91.4, max: 190)
#
# Run: 116, exploration: 0.05, score: 105
# Scores: (min: 12, avg: 92.28, max: 190)
#
# Run: 117, exploration: 0.05, score: 112
# Scores: (min: 12, avg: 93.18, max: 190)
#
# Run: 118, exploration: 0.05, score: 51
# Scores: (min: 12, avg: 93.47, max: 190)
#
# Run: 119, exploration: 0.05, score: 119
# Scores: (min: 12, avg: 94.36, max: 190)
#
# Run: 120, exploration: 0.05, score: 65
# Scores: (min: 15, avg: 94.89, max: 190)
#
# Run: 121, exploration: 0.05, score: 107
# Scores: (min: 15, avg: 95.64, max: 190)
#
# Run: 122, exploration: 0.05, score: 116
# Scores: (min: 16, avg: 96.65, max: 190)
#
# Run: 123, exploration: 0.05, score: 102
# Scores: (min: 16, avg: 97.35, max: 190)
#
# Run: 124, exploration: 0.05, score: 107
# Scores: (min: 18, avg: 98.26, max: 190)
#
# Run: 125, exploration: 0.05, score: 110
# Scores: (min: 18, avg: 99.18, max: 190)
#
# Run: 126, exploration: 0.05, score: 145
# Scores: (min: 18, avg: 100.4, max: 190)
#
# Run: 127, exploration: 0.05, score: 110
# Scores: (min: 18, avg: 100.96, max: 190)
#
# Run: 128, exploration: 0.05, score: 112
# Scores: (min: 18, avg: 101.5, max: 190)
#
# Run: 129, exploration: 0.05, score: 173
# Scores: (min: 18, avg: 102.66, max: 190)
#
# Run: 130, exploration: 0.05, score: 145
# Scores: (min: 18, avg: 103.78, max: 190)
#
# Run: 131, exploration: 0.05, score: 108
# Scores: (min: 18, avg: 104.19, max: 190)
#
# Run: 132, exploration: 0.05, score: 117
# Scores: (min: 18, avg: 105.1, max: 190)
#
# Run: 133, exploration: 0.05, score: 123
# Scores: (min: 18, avg: 105.99, max: 190)
#
# Run: 134, exploration: 0.05, score: 101
# Scores: (min: 19, avg: 106.82, max: 190)
#
# Run: 135, exploration: 0.05, score: 92
# Scores: (min: 19, avg: 107.28, max: 190)
#
# Run: 136, exploration: 0.05, score: 158
# Scores: (min: 19, avg: 108.37, max: 190)
#
# Run: 137, exploration: 0.05, score: 117
# Scores: (min: 19, avg: 108.84, max: 190)
#
# Run: 138, exploration: 0.05, score: 84
# Scores: (min: 19, avg: 109.34, max: 190)
#
# Run: 139, exploration: 0.05, score: 160
# Scores: (min: 19, avg: 109.93, max: 190)
#
# Run: 140, exploration: 0.05, score: 119
# Scores: (min: 50, avg: 110.93, max: 190)
#
# Run: 141, exploration: 0.05, score: 126
# Scores: (min: 50, avg: 111.56, max: 190)
#
# Run: 142, exploration: 0.05, score: 101
# Scores: (min: 51, avg: 112.07, max: 190)
#
# Run: 143, exploration: 0.05, score: 159
# Scores: (min: 51, avg: 112.75, max: 190)
#
# Run: 144, exploration: 0.05, score: 115
# Scores: (min: 51, avg: 113.34, max: 190)
#
# Run: 145, exploration: 0.05, score: 110
# Scores: (min: 51, avg: 113.66, max: 190)
#
# Run: 146, exploration: 0.05, score: 171
# Scores: (min: 51, avg: 114.35, max: 190)
#
# Run: 147, exploration: 0.05, score: 136
# Scores: (min: 51, avg: 115.04, max: 190)
#
# Run: 148, exploration: 0.05, score: 104
# Scores: (min: 51, avg: 115.1, max: 190)
#
# Run: 149, exploration: 0.05, score: 141
# Scores: (min: 51, avg: 115.44, max: 190)
#
# Run: 150, exploration: 0.05, score: 130
# Scores: (min: 51, avg: 115.76, max: 190)
#
# Run: 151, exploration: 0.05, score: 138
# Scores: (min: 51, avg: 115.94, max: 190)
#
# Run: 152, exploration: 0.05, score: 116
# Scores: (min: 51, avg: 115.2, max: 173)
#
# Run: 153, exploration: 0.05, score: 167
# Scores: (min: 51, avg: 115.14, max: 173)
#
# Run: 154, exploration: 0.05, score: 139
# Scores: (min: 51, avg: 115.63, max: 173)
#
# Run: 155, exploration: 0.05, score: 115
# Scores: (min: 51, avg: 115.4, max: 173)
#
# Run: 156, exploration: 0.05, score: 113
# Scores: (min: 51, avg: 115.55, max: 173)
#
# Run: 157, exploration: 0.05, score: 136
# Scores: (min: 51, avg: 115.73, max: 173)
#
# Run: 158, exploration: 0.05, score: 115
# Scores: (min: 51, avg: 115.63, max: 173)
#
# Run: 159, exploration: 0.05, score: 154
# Scores: (min: 51, avg: 115.99, max: 173)
#
# Run: 160, exploration: 0.05, score: 112
# Scores: (min: 51, avg: 115.79, max: 173)
#
# Run: 161, exploration: 0.05, score: 114
# Scores: (min: 51, avg: 115.8, max: 173)
#
# Run: 162, exploration: 0.05, score: 152
# Scores: (min: 51, avg: 116.22, max: 173)
#
# Run: 163, exploration: 0.05, score: 124
# Scores: (min: 51, avg: 116.34, max: 173)
#
# Run: 164, exploration: 0.05, score: 125
# Scores: (min: 51, avg: 116.23, max: 173)
#
# Run: 165, exploration: 0.05, score: 114
# Scores: (min: 51, avg: 116.19, max: 173)
#
# Run: 166, exploration: 0.05, score: 101
# Scores: (min: 51, avg: 116.2, max: 173)
#
# Run: 167, exploration: 0.05, score: 110
# Scores: (min: 51, avg: 116.28, max: 173)
#
# Run: 168, exploration: 0.05, score: 118
# Scores: (min: 51, avg: 116.16, max: 173)
#
# Run: 169, exploration: 0.05, score: 139
# Scores: (min: 51, avg: 115.87, max: 173)
#
# Run: 170, exploration: 0.05, score: 157
# Scores: (min: 51, avg: 116.24, max: 173)
#
# Run: 171, exploration: 0.05, score: 114
# Scores: (min: 51, avg: 116.22, max: 173)
#
# Run: 172, exploration: 0.05, score: 76
# Scores: (min: 51, avg: 115.98, max: 173)
#
# Run: 173, exploration: 0.05, score: 104
# Scores: (min: 51, avg: 115.87, max: 173)
#
# Run: 174, exploration: 0.05, score: 151
# Scores: (min: 51, avg: 116.23, max: 173)
#
# Run: 175, exploration: 0.05, score: 79
# Scores: (min: 51, avg: 116.05, max: 173)
#
# Run: 176, exploration: 0.05, score: 143
# Scores: (min: 51, avg: 116.46, max: 173)
#
# Run: 177, exploration: 0.05, score: 136
# Scores: (min: 51, avg: 116.54, max: 173)
#
# Run: 178, exploration: 0.05, score: 105
# Scores: (min: 51, avg: 116.35, max: 173)
#
# Run: 179, exploration: 0.05, score: 93
# Scores: (min: 51, avg: 116.14, max: 173)
#
# Run: 180, exploration: 0.05, score: 116
# Scores: (min: 51, avg: 116.2, max: 173)
#
# Run: 181, exploration: 0.05, score: 124
# Scores: (min: 51, avg: 116.38, max: 173)
#
# Run: 182, exploration: 0.05, score: 175
# Scores: (min: 51, avg: 117.36, max: 175)
#
# Run: 183, exploration: 0.05, score: 164
# Scores: (min: 51, avg: 117.81, max: 175)
#
# Run: 184, exploration: 0.05, score: 112
# Scores: (min: 51, avg: 117.79, max: 175)
#
# Run: 185, exploration: 0.05, score: 100
# Scores: (min: 51, avg: 117.73, max: 175)
#
# Run: 186, exploration: 0.05, score: 120
# Scores: (min: 51, avg: 117.76, max: 175)
#
# Run: 187, exploration: 0.05, score: 130
# Scores: (min: 51, avg: 117.9, max: 175)
#
# Run: 188, exploration: 0.05, score: 109
# Scores: (min: 51, avg: 117.9, max: 175)
#
# Run: 189, exploration: 0.05, score: 116
# Scores: (min: 51, avg: 117.86, max: 175)
#
# Run: 190, exploration: 0.05, score: 182
# Scores: (min: 51, avg: 118.59, max: 182)
#
# Run: 191, exploration: 0.05, score: 102
# Scores: (min: 51, avg: 118.47, max: 182)
#
# Run: 192, exploration: 0.05, score: 123
# Scores: (min: 51, avg: 118.59, max: 182)
#
# Run: 193, exploration: 0.05, score: 125
# Scores: (min: 51, avg: 118.78, max: 182)
#
# Run: 194, exploration: 0.05, score: 119
# Scores: (min: 51, avg: 118.94, max: 182)
#
# Run: 195, exploration: 0.05, score: 105
# Scores: (min: 51, avg: 118.92, max: 182)
#
# Run: 196, exploration: 0.05, score: 116
# Scores: (min: 51, avg: 119.02, max: 182)
#
# Run: 197, exploration: 0.05, score: 138
# Scores: (min: 51, avg: 119.25, max: 182)
#
# Run: 198, exploration: 0.05, score: 224
# Scores: (min: 51, avg: 120.47, max: 224)
#
# Run: 199, exploration: 0.05, score: 112
# Scores: (min: 51, avg: 120.54, max: 224)
#
# Run: 200, exploration: 0.05, score: 115
# Scores: (min: 51, avg: 120.63, max: 224)
#
# Run: 201, exploration: 0.05, score: 123
# Scores: (min: 51, avg: 120.85, max: 224)
#
# Run: 202, exploration: 0.05, score: 172
# Scores: (min: 51, avg: 121.46, max: 224)
#
# Run: 203, exploration: 0.05, score: 115
# Scores: (min: 51, avg: 121.57, max: 224)
#
# Run: 204, exploration: 0.05, score: 164
# Scores: (min: 51, avg: 122.11, max: 224)
#
# Run: 205, exploration: 0.05, score: 153
# Scores: (min: 51, avg: 122.62, max: 224)
#
# Run: 206, exploration: 0.05, score: 142
# Scores: (min: 51, avg: 122.93, max: 224)
#
# Run: 207, exploration: 0.05, score: 114
# Scores: (min: 51, avg: 122.99, max: 224)
#
# Run: 208, exploration: 0.05, score: 109
# Scores: (min: 51, avg: 123.03, max: 224)
#
# Run: 209, exploration: 0.05, score: 157
# Scores: (min: 51, avg: 123.52, max: 224)
#
# Run: 210, exploration: 0.05, score: 82
# Scores: (min: 51, avg: 123.15, max: 224)
#
# Run: 211, exploration: 0.05, score: 121
# Scores: (min: 51, avg: 123.26, max: 224)
#
# Run: 212, exploration: 0.05, score: 111
# Scores: (min: 51, avg: 123.26, max: 224)
#
# Run: 213, exploration: 0.05, score: 137
# Scores: (min: 51, avg: 123.56, max: 224)
#
# Run: 214, exploration: 0.05, score: 107
# Scores: (min: 51, avg: 123.57, max: 224)
#
# Run: 215, exploration: 0.05, score: 184
# Scores: (min: 51, avg: 124.29, max: 224)
#
# Run: 216, exploration: 0.05, score: 113
# Scores: (min: 51, avg: 124.37, max: 224)
#
# Run: 217, exploration: 0.05, score: 67
# Scores: (min: 51, avg: 123.92, max: 224)
#
# Run: 218, exploration: 0.05, score: 65
# Scores: (min: 65, avg: 124.06, max: 224)
#
# Run: 219, exploration: 0.05, score: 124
# Scores: (min: 65, avg: 124.11, max: 224)
#
# Run: 220, exploration: 0.05, score: 138
# Scores: (min: 65, avg: 124.84, max: 224)
#
# Run: 221, exploration: 0.05, score: 63
# Scores: (min: 63, avg: 124.4, max: 224)
#
# Run: 222, exploration: 0.05, score: 115
# Scores: (min: 63, avg: 124.39, max: 224)
#
# Run: 223, exploration: 0.05, score: 73
# Scores: (min: 63, avg: 124.1, max: 224)
#
# Run: 224, exploration: 0.05, score: 148
# Scores: (min: 63, avg: 124.51, max: 224)
#
# Run: 225, exploration: 0.05, score: 92
# Scores: (min: 63, avg: 124.33, max: 224)
#
# Run: 226, exploration: 0.05, score: 116
# Scores: (min: 63, avg: 124.04, max: 224)
#
# Run: 227, exploration: 0.05, score: 116
# Scores: (min: 63, avg: 124.1, max: 224)
#
# Run: 228, exploration: 0.05, score: 106
# Scores: (min: 63, avg: 124.04, max: 224)
#
# Run: 229, exploration: 0.05, score: 108
# Scores: (min: 63, avg: 123.39, max: 224)
#
# Run: 230, exploration: 0.05, score: 123
# Scores: (min: 63, avg: 123.17, max: 224)
#
# Run: 231, exploration: 0.05, score: 127
# Scores: (min: 63, avg: 123.36, max: 224)
#
# Run: 232, exploration: 0.05, score: 192
# Scores: (min: 63, avg: 124.11, max: 224)
#
# Run: 233, exploration: 0.05, score: 115
# Scores: (min: 63, avg: 124.03, max: 224)
#
# Run: 234, exploration: 0.05, score: 135
# Scores: (min: 63, avg: 124.37, max: 224)
#
# Run: 235, exploration: 0.05, score: 168
# Scores: (min: 63, avg: 125.13, max: 224)
#
# Run: 236, exploration: 0.05, score: 140
# Scores: (min: 63, avg: 124.95, max: 224)
#
# Run: 237, exploration: 0.05, score: 121
# Scores: (min: 63, avg: 124.99, max: 224)
#
# Run: 238, exploration: 0.05, score: 117
# Scores: (min: 63, avg: 125.32, max: 224)
#
# Run: 239, exploration: 0.05, score: 150
# Scores: (min: 63, avg: 125.22, max: 224)
#
# Run: 240, exploration: 0.05, score: 102
# Scores: (min: 63, avg: 125.05, max: 224)
#
# Run: 241, exploration: 0.05, score: 131
# Scores: (min: 63, avg: 125.1, max: 224)
#
# Run: 242, exploration: 0.05, score: 144
# Scores: (min: 63, avg: 125.53, max: 224)
#
# Run: 243, exploration: 0.05, score: 114
# Scores: (min: 63, avg: 125.08, max: 224)
#
# Run: 244, exploration: 0.05, score: 130
# Scores: (min: 63, avg: 125.23, max: 224)
#
# Run: 245, exploration: 0.05, score: 140
# Scores: (min: 63, avg: 125.53, max: 224)
#
# Run: 246, exploration: 0.05, score: 125
# Scores: (min: 63, avg: 125.07, max: 224)
#
# Run: 247, exploration: 0.05, score: 133
# Scores: (min: 63, avg: 125.04, max: 224)
#
# Run: 248, exploration: 0.05, score: 108
# Scores: (min: 63, avg: 125.08, max: 224)
#
# Run: 249, exploration: 0.05, score: 122
# Scores: (min: 63, avg: 124.89, max: 224)
#
# Run: 250, exploration: 0.05, score: 163
# Scores: (min: 63, avg: 125.22, max: 224)
#
# Run: 251, exploration: 0.05, score: 135
# Scores: (min: 63, avg: 125.19, max: 224)
#
# Run: 252, exploration: 0.05, score: 122
# Scores: (min: 63, avg: 125.25, max: 224)
#
# Run: 253, exploration: 0.05, score: 133
# Scores: (min: 63, avg: 124.91, max: 224)
#
# Run: 254, exploration: 0.05, score: 122
# Scores: (min: 63, avg: 124.74, max: 224)
#
# Run: 255, exploration: 0.05, score: 216
# Scores: (min: 63, avg: 125.75, max: 224)
#
# Run: 256, exploration: 0.05, score: 122
# Scores: (min: 63, avg: 125.84, max: 224)
#
# Run: 257, exploration: 0.05, score: 133
# Scores: (min: 63, avg: 125.81, max: 224)
#
# Run: 258, exploration: 0.05, score: 104
# Scores: (min: 63, avg: 125.7, max: 224)
#
# Run: 259, exploration: 0.05, score: 65
# Scores: (min: 63, avg: 124.81, max: 224)
#
# Run: 260, exploration: 0.05, score: 83
# Scores: (min: 63, avg: 124.52, max: 224)
#
# Run: 261, exploration: 0.05, score: 104
# Scores: (min: 63, avg: 124.42, max: 224)
#
# Run: 262, exploration: 0.05, score: 95
# Scores: (min: 63, avg: 123.85, max: 224)
#
# Run: 263, exploration: 0.05, score: 91
# Scores: (min: 63, avg: 123.52, max: 224)
#
# Run: 264, exploration: 0.05, score: 71
# Scores: (min: 63, avg: 122.98, max: 224)
#
# Run: 265, exploration: 0.05, score: 145
# Scores: (min: 63, avg: 123.29, max: 224)
#
# Run: 266, exploration: 0.05, score: 141
# Scores: (min: 63, avg: 123.69, max: 224)
#
# Run: 267, exploration: 0.05, score: 161
# Scores: (min: 63, avg: 124.2, max: 224)
#
# Run: 268, exploration: 0.05, score: 114
# Scores: (min: 63, avg: 124.16, max: 224)
#
# Run: 269, exploration: 0.05, score: 134
# Scores: (min: 63, avg: 124.11, max: 224)
#
# Run: 270, exploration: 0.05, score: 143
# Scores: (min: 63, avg: 123.97, max: 224)
#
# Run: 271, exploration: 0.05, score: 118
# Scores: (min: 63, avg: 124.01, max: 224)
#
# Run: 272, exploration: 0.05, score: 136
# Scores: (min: 63, avg: 124.61, max: 224)
#
# Run: 273, exploration: 0.05, score: 156
# Scores: (min: 63, avg: 125.13, max: 224)
#
# Run: 274, exploration: 0.05, score: 207
# Scores: (min: 63, avg: 125.69, max: 224)
#
# Run: 275, exploration: 0.05, score: 165
# Scores: (min: 63, avg: 126.55, max: 224)
#
# Run: 276, exploration: 0.05, score: 158
# Scores: (min: 63, avg: 126.7, max: 224)
#
# Run: 277, exploration: 0.05, score: 126
# Scores: (min: 63, avg: 126.6, max: 224)
#
# Run: 278, exploration: 0.05, score: 153
# Scores: (min: 63, avg: 127.08, max: 224)
#
# Run: 279, exploration: 0.05, score: 121
# Scores: (min: 63, avg: 127.36, max: 224)
#
# Run: 280, exploration: 0.05, score: 166
# Scores: (min: 63, avg: 127.86, max: 224)
#
# Run: 281, exploration: 0.05, score: 159
# Scores: (min: 63, avg: 128.21, max: 224)
#
# Run: 282, exploration: 0.05, score: 206
# Scores: (min: 63, avg: 128.52, max: 224)
#
# Run: 283, exploration: 0.05, score: 121
# Scores: (min: 63, avg: 128.09, max: 224)
#
# Run: 284, exploration: 0.05, score: 238
# Scores: (min: 63, avg: 129.35, max: 238)
#
# Run: 285, exploration: 0.05, score: 246
# Scores: (min: 63, avg: 130.81, max: 246)
# Run: 286, exploration: 0.05, score: 122
# Scores: (min: 63, avg: 130.83, max: 246)
#
# Run: 287, exploration: 0.05, score: 125
# Scores: (min: 63, avg: 130.78, max: 246)
#
# Run: 288, exploration: 0.05, score: 129
# Scores: (min: 63, avg: 130.98, max: 246)
#
# Run: 289, exploration: 0.05, score: 152
# Scores: (min: 63, avg: 131.34, max: 246)
#
# Run: 290, exploration: 0.05, score: 158
# Scores: (min: 63, avg: 131.1, max: 246)
#
# Run: 291, exploration: 0.05, score: 100
# Scores: (min: 63, avg: 131.08, max: 246)
#
# Run: 292, exploration: 0.05, score: 137
# Scores: (min: 63, avg: 131.22, max: 246)
#
# Run: 293, exploration: 0.05, score: 131
# Scores: (min: 63, avg: 131.28, max: 246)
#
# Run: 294, exploration: 0.05, score: 157
# Scores: (min: 63, avg: 131.66, max: 246)
#
# Run: 295, exploration: 0.05, score: 206
# Scores: (min: 63, avg: 132.67, max: 246)
#
# Run: 296, exploration: 0.05, score: 124
# Scores: (min: 63, avg: 132.75, max: 246)
#
# Run: 297, exploration: 0.05, score: 131
# Scores: (min: 63, avg: 132.68, max: 246)
#
# Run: 298, exploration: 0.05, score: 184
# Scores: (min: 63, avg: 132.28, max: 246)
#
# Run: 299, exploration: 0.05, score: 72
# Scores: (min: 63, avg: 131.88, max: 246)
#
# Run: 300, exploration: 0.05, score: 193
# Scores: (min: 63, avg: 132.66, max: 246)
#
# Run: 301, exploration: 0.05, score: 249
# Scores: (min: 63, avg: 133.92, max: 249)
#
# Run: 302, exploration: 0.05, score: 120
# Scores: (min: 63, avg: 133.4, max: 249)
#
# Run: 303, exploration: 0.05, score: 130
# Scores: (min: 63, avg: 133.55, max: 249)
#
# Run: 304, exploration: 0.05, score: 149
# Scores: (min: 63, avg: 133.4, max: 249)
#
# Run: 305, exploration: 0.05, score: 60
# Scores: (min: 60, avg: 132.47, max: 249)
#
# Run: 306, exploration: 0.05, score: 133
# Scores: (min: 60, avg: 132.38, max: 249)
#
# Run: 307, exploration: 0.05, score: 163
# Scores: (min: 60, avg: 132.87, max: 249)
#
# Run: 308, exploration: 0.05, score: 207
# Scores: (min: 60, avg: 133.85, max: 249)
#
# Run: 309, exploration: 0.05, score: 150
# Scores: (min: 60, avg: 133.78, max: 249)
#
# Run: 310, exploration: 0.05, score: 142
# Scores: (min: 60, avg: 134.38, max: 249)
#
# Run: 311, exploration: 0.05, score: 126
# Scores: (min: 60, avg: 134.43, max: 249)
#
# Run: 312, exploration: 0.05, score: 209
# Scores: (min: 60, avg: 135.41, max: 249)
#
# Run: 313, exploration: 0.05, score: 124
# Scores: (min: 60, avg: 135.28, max: 249)
#
# Run: 314, exploration: 0.05, score: 152
# Scores: (min: 60, avg: 135.73, max: 249)
#
# Run: 315, exploration: 0.05, score: 108
# Scores: (min: 60, avg: 134.97, max: 249)
#
# Run: 316, exploration: 0.05, score: 134
# Scores: (min: 60, avg: 135.18, max: 249)
#
# Run: 317, exploration: 0.05, score: 149
# Scores: (min: 60, avg: 136, max: 249)
#
# Run: 318, exploration: 0.05, score: 146
# Scores: (min: 60, avg: 136.81, max: 249)
#
# Run: 319, exploration: 0.05, score: 133
# Scores: (min: 60, avg: 136.9, max: 249)
#
# Run: 320, exploration: 0.05, score: 211
# Scores: (min: 60, avg: 137.63, max: 249)
#
# Run: 321, exploration: 0.05, score: 147
# Scores: (min: 60, avg: 138.47, max: 249)
#
# Run: 322, exploration: 0.05, score: 128
# Scores: (min: 60, avg: 138.6, max: 249)
#
# Run: 323, exploration: 0.05, score: 99
# Scores: (min: 60, avg: 138.86, max: 249)
#
# Run: 324, exploration: 0.05, score: 68
# Scores: (min: 60, avg: 138.06, max: 249)
#
# Run: 325, exploration: 0.05, score: 151
# Scores: (min: 60, avg: 138.65, max: 249)
#
# Run: 326, exploration: 0.05, score: 82
# Scores: (min: 60, avg: 138.31, max: 249)
#
# Run: 327, exploration: 0.05, score: 115
# Scores: (min: 60, avg: 138.3, max: 249)
#
# Run: 328, exploration: 0.05, score: 113
# Scores: (min: 60, avg: 138.37, max: 249)
#
# Run: 329, exploration: 0.05, score: 180
# Scores: (min: 60, avg: 139.09, max: 249)
#
# Run: 330, exploration: 0.05, score: 135
# Scores: (min: 60, avg: 139.21, max: 249)
#
# Run: 331, exploration: 0.05, score: 190
# Scores: (min: 60, avg: 139.84, max: 249)
#
# Run: 332, exploration: 0.05, score: 128
# Scores: (min: 60, avg: 139.2, max: 249)
#
# Run: 333, exploration: 0.05, score: 140
# Scores: (min: 60, avg: 139.45, max: 249)
#
# Run: 334, exploration: 0.05, score: 147
# Scores: (min: 60, avg: 139.57, max: 249)
#
# Run: 335, exploration: 0.05, score: 102
# Scores: (min: 60, avg: 138.91, max: 249)
#
# Run: 336, exploration: 0.05, score: 126
# Scores: (min: 60, avg: 138.77, max: 249)
#
# Run: 337, exploration: 0.05, score: 252
# Scores: (min: 60, avg: 140.08, max: 252)
#
# Run: 338, exploration: 0.05, score: 168
# Scores: (min: 60, avg: 140.59, max: 252)
#
# Run: 339, exploration: 0.05, score: 115
# Scores: (min: 60, avg: 140.24, max: 252)
#
# Run: 340, exploration: 0.05, score: 162
# Scores: (min: 60, avg: 140.84, max: 252)
#
# Run: 341, exploration: 0.05, score: 159
# Scores: (min: 60, avg: 141.12, max: 252)
#
# Run: 342, exploration: 0.05, score: 148
# Scores: (min: 60, avg: 141.16, max: 252)
#
# Run: 343, exploration: 0.05, score: 173
# Scores: (min: 60, avg: 141.75, max: 252)
#
# Run: 344, exploration: 0.05, score: 127
# Scores: (min: 60, avg: 141.72, max: 252)
#
# Run: 345, exploration: 0.05, score: 110
# Scores: (min: 60, avg: 141.42, max: 252)
#
# Run: 346, exploration: 0.05, score: 82
# Scores: (min: 60, avg: 140.99, max: 252)
#
# Run: 347, exploration: 0.05, score: 105
# Scores: (min: 60, avg: 140.71, max: 252)
#
# Run: 348, exploration: 0.05, score: 112
# Scores: (min: 60, avg: 140.75, max: 252)
#
# Run: 349, exploration: 0.05, score: 105
# Scores: (min: 60, avg: 140.58, max: 252)
#
# Run: 350, exploration: 0.05, score: 133
# Scores: (min: 60, avg: 140.28, max: 252)
#
# Run: 351, exploration: 0.05, score: 253
# Scores: (min: 60, avg: 141.46, max: 253)
#
# Run: 352, exploration: 0.05, score: 63
# Scores: (min: 60, avg: 140.87, max: 253)
#
# Run: 353, exploration: 0.05, score: 222
# Scores: (min: 60, avg: 141.76, max: 253)
#
# Run: 354, exploration: 0.05, score: 336
# Scores: (min: 60, avg: 143.9, max: 336)
#
# Run: 355, exploration: 0.05, score: 132
# Scores: (min: 60, avg: 143.06, max: 336)
#
# Run: 356, exploration: 0.05, score: 128
# Scores: (min: 60, avg: 143.12, max: 336)
#
# Run: 357, exploration: 0.05, score: 166
# Scores: (min: 60, avg: 143.45, max: 336)
#
# Run: 358, exploration: 0.05, score: 257
# Scores: (min: 60, avg: 144.98, max: 336)
#
# Run: 359, exploration: 0.05, score: 166
# Scores: (min: 60, avg: 145.99, max: 336)
#
# Run: 360, exploration: 0.05, score: 157
# Scores: (min: 60, avg: 146.73, max: 336)
#
# Run: 361, exploration: 0.05, score: 139
# Scores: (min: 60, avg: 147.08, max: 336)
#
# Run: 362, exploration: 0.05, score: 133
# Scores: (min: 60, avg: 147.46, max: 336)
#
# Run: 363, exploration: 0.05, score: 129
# Scores: (min: 60, avg: 147.84, max: 336)
#
# Run: 364, exploration: 0.05, score: 129
# Scores: (min: 60, avg: 148.42, max: 336)
#
# Run: 365, exploration: 0.05, score: 133
# Scores: (min: 60, avg: 148.3, max: 336)
#
# Run: 366, exploration: 0.05, score: 131
# Scores: (min: 60, avg: 148.2, max: 336)
#
# Run: 367, exploration: 0.05, score: 153
# Scores: (min: 60, avg: 148.12, max: 336)
#
# Run: 368, exploration: 0.05, score: 127
# Scores: (min: 60, avg: 148.25, max: 336)
#
# Run: 369, exploration: 0.05, score: 118
# Scores: (min: 60, avg: 148.09, max: 336)
#
# Run: 370, exploration: 0.05, score: 119
# Scores: (min: 60, avg: 147.85, max: 336)
#
# Run: 371, exploration: 0.05, score: 127
# Scores: (min: 60, avg: 147.94, max: 336)
#
# Run: 372, exploration: 0.05, score: 123
# Scores: (min: 60, avg: 147.81, max: 336)
#
# Run: 373, exploration: 0.05, score: 82
# Scores: (min: 60, avg: 147.07, max: 336)
#
# Run: 374, exploration: 0.05, score: 134
# Scores: (min: 60, avg: 146.34, max: 336)
#
# Run: 375, exploration: 0.05, score: 132
# Scores: (min: 60, avg: 146.01, max: 336)
#
# Run: 376, exploration: 0.05, score: 63
# Scores: (min: 60, avg: 145.06, max: 336)
#
# Run: 377, exploration: 0.05, score: 125
# Scores: (min: 60, avg: 145.05, max: 336)
#
# Run: 378, exploration: 0.05, score: 161
# Scores: (min: 60, avg: 145.13, max: 336)
#
# Run: 379, exploration: 0.05, score: 134
# Scores: (min: 60, avg: 145.26, max: 336)
#
# Run: 380, exploration: 0.05, score: 145
# Scores: (min: 60, avg: 145.05, max: 336)
#
# Run: 381, exploration: 0.05, score: 224
# Scores: (min: 60, avg: 145.7, max: 336)
#
# Run: 382, exploration: 0.05, score: 140
# Scores: (min: 60, avg: 145.04, max: 336)
#
# Run: 383, exploration: 0.05, score: 167
# Scores: (min: 60, avg: 145.5, max: 336)
#
# Run: 384, exploration: 0.05, score: 158
# Scores: (min: 60, avg: 144.7, max: 336)
#
# Run: 385, exploration: 0.05, score: 222
# Scores: (min: 60, avg: 144.46, max: 336)
#
# Run: 386, exploration: 0.05, score: 152
# Scores: (min: 60, avg: 144.76, max: 336)
#
# Run: 387, exploration: 0.05, score: 141
# Scores: (min: 60, avg: 144.92, max: 336)
#
# Run: 388, exploration: 0.05, score: 160
# Scores: (min: 60, avg: 145.23, max: 336)
#
# Run: 389, exploration: 0.05, score: 181
# Scores: (min: 60, avg: 145.52, max: 336)
#
# Run: 390, exploration: 0.05, score: 153
# Scores: (min: 60, avg: 145.47, max: 336)
#
# Run: 391, exploration: 0.05, score: 191
# Scores: (min: 60, avg: 146.38, max: 336)
#
# Run: 392, exploration: 0.05, score: 194
# Scores: (min: 60, avg: 146.95, max: 336)
#
# Run: 393, exploration: 0.05, score: 207
# Scores: (min: 60, avg: 147.71, max: 336)
#
# Run: 394, exploration: 0.05, score: 127
# Scores: (min: 60, avg: 147.41, max: 336)
#
# Run: 395, exploration: 0.05, score: 229
# Scores: (min: 60, avg: 147.64, max: 336)
#
# Run: 396, exploration: 0.05, score: 119
# Scores: (min: 60, avg: 147.59, max: 336)
#
# Run: 397, exploration: 0.05, score: 123
# Scores: (min: 60, avg: 147.51, max: 336)
#
# Run: 398, exploration: 0.05, score: 54
# Scores: (min: 54, avg: 146.21, max: 336)
#
# Run: 399, exploration: 0.05, score: 72
# Scores: (min: 54, avg: 146.21, max: 336)
#
# Run: 400, exploration: 0.05, score: 223
# Scores: (min: 54, avg: 146.51, max: 336)
#
# Run: 401, exploration: 0.05, score: 281
# Scores: (min: 54, avg: 146.83, max: 336)
#
# Run: 402, exploration: 0.05, score: 425
# Scores: (min: 54, avg: 149.88, max: 425)
#
# Run: 403, exploration: 0.05, score: 239
# Scores: (min: 54, avg: 150.97, max: 425)
#
# Run: 404, exploration: 0.05, score: 107
# Scores: (min: 54, avg: 150.55, max: 425)
#
# Run: 405, exploration: 0.05, score: 149
# Scores: (min: 54, avg: 151.44, max: 425)
#
# Run: 406, exploration: 0.05, score: 111
# Scores: (min: 54, avg: 151.22, max: 425)
#
# Run: 407, exploration: 0.05, score: 126
# Scores: (min: 54, avg: 150.85, max: 425)
#
# Run: 408, exploration: 0.05, score: 262
# Scores: (min: 54, avg: 151.4, max: 425)
#
# Run: 409, exploration: 0.05, score: 134
# Scores: (min: 54, avg: 151.24, max: 425)
#
# Run: 410, exploration: 0.05, score: 137
# Scores: (min: 54, avg: 151.19, max: 425)
#
# Run: 411, exploration: 0.05, score: 165
# Scores: (min: 54, avg: 151.58, max: 425)
#
# Run: 412, exploration: 0.05, score: 206
# Scores: (min: 54, avg: 151.55, max: 425)
#
# Run: 413, exploration: 0.05, score: 206
# Scores: (min: 54, avg: 152.37, max: 425)
#
# Run: 414, exploration: 0.05, score: 136
# Scores: (min: 54, avg: 152.21, max: 425)
#
# Run: 415, exploration: 0.05, score: 154
# Scores: (min: 54, avg: 152.67, max: 425)
#
# Run: 416, exploration: 0.05, score: 143
# Scores: (min: 54, avg: 152.76, max: 425)
#
# Run: 417, exploration: 0.05, score: 188
# Scores: (min: 54, avg: 153.15, max: 425)
#
# Run: 418, exploration: 0.05, score: 129
# Scores: (min: 54, avg: 152.98, max: 425)
#
# Run: 419, exploration: 0.05, score: 125
# Scores: (min: 54, avg: 152.9, max: 425)
#
# Run: 420, exploration: 0.05, score: 182
# Scores: (min: 54, avg: 152.61, max: 425)
#
# Run: 421, exploration: 0.05, score: 130
# Scores: (min: 54, avg: 152.44, max: 425)
#
# Run: 422, exploration: 0.05, score: 124
# Scores: (min: 54, avg: 152.4, max: 425)
#
# Run: 423, exploration: 0.05, score: 174
# Scores: (min: 54, avg: 153.15, max: 425)
#
# Run: 424, exploration: 0.05, score: 398
# Scores: (min: 54, avg: 156.45, max: 425)
#
# Run: 425, exploration: 0.05, score: 196
# Scores: (min: 54, avg: 156.9, max: 425)
#
# Run: 426, exploration: 0.05, score: 394
# Scores: (min: 54, avg: 160.02, max: 425)
#
# Run: 427, exploration: 0.05, score: 487
# Scores: (min: 54, avg: 163.74, max: 487)
#
# Run: 428, exploration: 0.05, score: 210
# Scores: (min: 54, avg: 164.71, max: 487)
#
# Run: 429, exploration: 0.05, score: 193
# Scores: (min: 54, avg: 164.84, max: 487)
#
# Run: 430, exploration: 0.05, score: 185
# Scores: (min: 54, avg: 165.34, max: 487)
#
# Run: 431, exploration: 0.05, score: 146
# Scores: (min: 54, avg: 164.9, max: 487)
#
# Run: 432, exploration: 0.05, score: 233
# Scores: (min: 54, avg: 165.95, max: 487)
#
# Run: 433, exploration: 0.05, score: 33
# Scores: (min: 33, avg: 164.88, max: 487)
#
# Run: 434, exploration: 0.05, score: 213
# Scores: (min: 33, avg: 165.54, max: 487)
#
# Run: 435, exploration: 0.05, score: 195
# Scores: (min: 33, avg: 166.47, max: 487)
#
# Run: 436, exploration: 0.05, score: 245
# Scores: (min: 33, avg: 167.66, max: 487)
#
# Run: 437, exploration: 0.05, score: 192
# Scores: (min: 33, avg: 167.06, max: 487)
#
# Run: 438, exploration: 0.05, score: 282
# Scores: (min: 33, avg: 168.2, max: 487)
#
# Run: 439, exploration: 0.05, score: 87
# Scores: (min: 33, avg: 167.92, max: 487)
#
# Run: 440, exploration: 0.05, score: 500
# Scores: (min: 33, avg: 171.3, max: 500)
#
# Run: 441, exploration: 0.05, score: 334
# Scores: (min: 33, avg: 173.05, max: 500)
#
# Run: 442, exploration: 0.05, score: 277
# Scores: (min: 33, avg: 174.34, max: 500)
#
# Run: 443, exploration: 0.05, score: 320
# Scores: (min: 33, avg: 175.81, max: 500)
#
# Run: 444, exploration: 0.05, score: 239
# Scores: (min: 33, avg: 176.93, max: 500)
#
# Run: 445, exploration: 0.05, score: 500
# Scores: (min: 33, avg: 180.83, max: 500)
#
# Run: 446, exploration: 0.05, score: 211
# Scores: (min: 33, avg: 182.12, max: 500)
#
# Run: 447, exploration: 0.05, score: 189
# Scores: (min: 33, avg: 182.96, max: 500)
#
# Run: 448, exploration: 0.05, score: 132
# Scores: (min: 33, avg: 183.16, max: 500)
#
# Run: 449, exploration: 0.05, score: 174
# Scores: (min: 33, avg: 183.85, max: 500)
#
# Run: 450, exploration: 0.05, score: 126
# Scores: (min: 33, avg: 183.78, max: 500)
#
# Run: 451, exploration: 0.05, score: 119
# Scores: (min: 33, avg: 182.44, max: 500)
#
# Run: 452, exploration: 0.05, score: 144
# Scores: (min: 33, avg: 183.25, max: 500)
#
# Run: 453, exploration: 0.05, score: 105
# Scores: (min: 33, avg: 182.08, max: 500)
#
# Run: 454, exploration: 0.05, score: 113
# Scores: (min: 33, avg: 179.85, max: 500)
#
# Run: 455, exploration: 0.05, score: 105
# Scores: (min: 33, avg: 179.58, max: 500)
#
# Run: 456, exploration: 0.05, score: 172
# Scores: (min: 33, avg: 180.02, max: 500)
#
# Run: 457, exploration: 0.05, score: 105
# Scores: (min: 33, avg: 179.41, max: 500)
#
# Run: 458, exploration: 0.05, score: 140
# Scores: (min: 33, avg: 178.24, max: 500)
#
# Run: 459, exploration: 0.05, score: 201
# Scores: (min: 33, avg: 178.59, max: 500)
#
# Run: 460, exploration: 0.05, score: 160
# Scores: (min: 33, avg: 178.62, max: 500)
#
# Run: 461, exploration: 0.05, score: 201
# Scores: (min: 33, avg: 179.24, max: 500)
#
# Run: 462, exploration: 0.05, score: 115
# Scores: (min: 33, avg: 179.06, max: 500)
#
# Run: 463, exploration: 0.05, score: 356
# Scores: (min: 33, avg: 181.33, max: 500)
#
# Run: 464, exploration: 0.05, score: 228
# Scores: (min: 33, avg: 182.32, max: 500)
#
# Run: 465, exploration: 0.05, score: 500
# Scores: (min: 33, avg: 185.99, max: 500)
#
# Run: 466, exploration: 0.05, score: 204
# Scores: (min: 33, avg: 186.72, max: 500)
#
# Run: 467, exploration: 0.05, score: 199
# Scores: (min: 33, avg: 187.18, max: 500)
#
# Run: 468, exploration: 0.05, score: 338
# Scores: (min: 33, avg: 189.29, max: 500)
#
# Run: 469, exploration: 0.05, score: 83
# Scores: (min: 33, avg: 188.94, max: 500)
#
# Run: 470, exploration: 0.05, score: 80
# Scores: (min: 33, avg: 188.55, max: 500)
#
# Run: 471, exploration: 0.05, score: 120
# Scores: (min: 33, avg: 188.48, max: 500)
#
# Run: 472, exploration: 0.05, score: 69
# Scores: (min: 33, avg: 187.94, max: 500)
#
# Run: 473, exploration: 0.05, score: 183
# Scores: (min: 33, avg: 188.95, max: 500)
#
# Run: 474, exploration: 0.05, score: 130
# Scores: (min: 33, avg: 188.91, max: 500)
#
# Run: 475, exploration: 0.05, score: 84
# Scores: (min: 33, avg: 188.43, max: 500)
#
# Run: 476, exploration: 0.05, score: 120
# Scores: (min: 33, avg: 189, max: 500)
#
# Run: 477, exploration: 0.05, score: 122
# Scores: (min: 33, avg: 188.97, max: 500)
#
# Run: 478, exploration: 0.05, score: 190
# Scores: (min: 33, avg: 189.26, max: 500)
#
# Run: 479, exploration: 0.05, score: 106
# Scores: (min: 33, avg: 188.98, max: 500)
#
# Run: 480, exploration: 0.05, score: 271
# Scores: (min: 33, avg: 190.24, max: 500)
#
# Run: 481, exploration: 0.05, score: 199
# Scores: (min: 33, avg: 189.99, max: 500)
#
# Run: 482, exploration: 0.05, score: 231
# Scores: (min: 33, avg: 190.9, max: 500)
#
# Run: 483, exploration: 0.05, score: 215
# Scores: (min: 33, avg: 191.38, max: 500)
#
# Run: 484, exploration: 0.05, score: 176
# Scores: (min: 33, avg: 191.56, max: 500)
#
# Run: 485, exploration: 0.05, score: 184
# Scores: (min: 33, avg: 191.18, max: 500)
#
# Run: 486, exploration: 0.05, score: 164
# Scores: (min: 33, avg: 191.3, max: 500)
# Run: 487, exploration: 0.05, score: 179
# Scores: (min: 33, avg: 191.68, max: 500)
#
# Run: 488, exploration: 0.05, score: 216
# Scores: (min: 33, avg: 192.24, max: 500)
#
# Run: 489, exploration: 0.05, score: 172
# Scores: (min: 33, avg: 192.15, max: 500)
#
# Run: 490, exploration: 0.05, score: 157
# Scores: (min: 33, avg: 192.19, max: 500)
#
# Run: 491, exploration: 0.05, score: 213
# Scores: (min: 33, avg: 192.41, max: 500)
#
# Run: 492, exploration: 0.05, score: 175
# Scores: (min: 33, avg: 192.22, max: 500)
#
# Run: 493, exploration: 0.05, score: 192
# Scores: (min: 33, avg: 192.07, max: 500)
#
# Run: 494, exploration: 0.05, score: 188
# Scores: (min: 33, avg: 192.68, max: 500)
#
# Run: 495, exploration: 0.05, score: 239
# Scores: (min: 33, avg: 192.78, max: 500)
#
# Run: 496, exploration: 0.05, score: 176
# Scores: (min: 33, avg: 193.35, max: 500)
#
# Run: 497, exploration: 0.05, score: 182
# Scores: (min: 33, avg: 193.94, max: 500)
#
# Run: 498, exploration: 0.05, score: 185
# Scores: (min: 33, avg: 195.25, max: 500)
#
# Solved in 398 runs, 498 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3f2c2c1f880f> in <module>()
#      21         if terminal:
#      22             print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 23             score_logger.add_score(step, run)
#      24             break
#      25     dqn_solver.experience_replay()
#
# G:\GitProjects\cartpole\scores\score_logger.py in add_score(self, score, run)
#      52                            show_trend=False,
#      53                            show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined
